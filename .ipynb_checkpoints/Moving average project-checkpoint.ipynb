# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# MSFT =  mcrosoft 
df = yf.download('^NSEI', start = '2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2023-01-02  18131.699219  18215.150391  18086.500000  18197.449219
# 2023-01-03  18163.199219  18251.949219  18149.800781  18232.550781
# 2023-01-04  18230.650391  18243.000000  18020.599609  18042.949219
# 2023-01-05  18101.949219  18120.300781  17892.599609  17992.150391
# 2023-01-06  18008.050781  18047.400391  17795.550781  17859.449219
# ...                  ...           ...           ...           ...
# 2024-03-28  22163.599609  22516.000000  22163.599609  22326.900391
# 2024-04-01  22455.000000  22529.949219  22427.750000  22462.000000
# 2024-04-02  22458.800781  22497.599609  22388.150391  22453.300781
# 2024-04-03  22385.699219  22521.099609  22346.500000  22434.650391
# 2024-04-04  22592.099609  22619.000000  22303.800781  22514.650391
#
#                Adj Close  Volume
# Date
# 2023-01-02  18197.449219  256100
# 2023-01-03  18232.550781  208700
# 2023-01-04  18042.949219  235200
# 2023-01-05  17992.150391  269900
# 2023-01-06  17859.449219  238200
# ...                  ...     ...
# 2024-03-28  22326.900391  410500
# 2024-04-01  22462.000000       0
# 2024-04-02  22453.300781  289500
# 2024-04-03  22434.650391  309600
# 2024-04-04  22514.650391       0
#
# [309 rows x 6 columns]

# %%
df['MA20'] = df['Adj Close'].rolling(20).mean()
df['MA50'] = df['Adj Close'].rolling(50).mean()

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2023-01-02  18131.699219  18215.150391  18086.500000  18197.449219
# 2023-01-03  18163.199219  18251.949219  18149.800781  18232.550781
# 2023-01-04  18230.650391  18243.000000  18020.599609  18042.949219
# 2023-01-05  18101.949219  18120.300781  17892.599609  17992.150391
# 2023-01-06  18008.050781  18047.400391  17795.550781  17859.449219
# ...                  ...           ...           ...           ...
# 2024-03-28  22163.599609  22516.000000  22163.599609  22326.900391
# 2024-04-01  22455.000000  22529.949219  22427.750000  22462.000000
# 2024-04-02  22458.800781  22497.599609  22388.150391  22453.300781
# 2024-04-03  22385.699219  22521.099609  22346.500000  22434.650391
# 2024-04-04  22592.099609  22619.000000  22303.800781  22514.650391
#
#                Adj Close  Volume          MA20          MA50
# Date
# 2023-01-02  18197.449219  256100           NaN           NaN
# 2023-01-03  18232.550781  208700           NaN           NaN
# 2023-01-04  18042.949219  235200           NaN           NaN
# 2023-01-05  17992.150391  269900           NaN           NaN
# 2023-01-06  17859.449219  238200           NaN           NaN
# ...                  ...     ...           ...           ...
# 2024-03-28  22326.900391  410500  22155.722461  21957.808906
# 2024-04-01  22462.000000       0  22181.264941  21965.099922
# 2024-04-02  22453.300781  289500  22204.789941  21973.519922
# 2024-04-03  22434.650391  309600  22209.584961  21990.773945
# 2024-04-04  22514.650391       0  22215.037500  22011.821953
#
# [309 rows x 8 columns]

# %%
df = df.dropna()

# %%
df = df[['Adj Close','MA20','MA50']]

# %%
df
# Out:
#                Adj Close          MA20          MA50
# Date
# 2023-03-14  17043.300781  17592.907422  17783.223906
# 2023-03-15  16972.150391  17545.022461  17758.717930
# 2023-03-16  16985.599609  17493.509961  17733.778906
# 2023-03-17  17100.050781  17446.720020  17714.920937
# 2023-03-20  16988.400391  17398.930078  17694.845937
# ...                  ...           ...           ...
# 2024-03-28  22326.900391  22155.722461  21957.808906
# 2024-04-01  22462.000000  22181.264941  21965.099922
# 2024-04-02  22453.300781  22204.789941  21973.519922
# 2024-04-03  22434.650391  22209.584961  21990.773945
# 2024-04-04  22514.650391  22215.037500  22011.821953
#
# [260 rows x 3 columns]

# %%
Buy = []
Sell = []

for i in range(len(df)):
    if df.MA20.iloc[i] > df.MA50[i] \
    and df.MA20.iloc[i-1] < df.MA50[i-1]:
        Buy.append(i)
    elif df.MA20.iloc[i] < df.MA50[i] \
    and df.MA20.iloc[i-1] > df.MA50[i-1]:
        Sell.append(i)

# %%
Buy
# Out:
# [27, 126, 175]

# %%
Sell
# Out:
# [0, 116, 151]

# %%
plt.figure(figsize=(15, 7), facecolor='lightgray', edgecolor='black')
plt.plot(df['Adj Close'], label = 'Asset Price', c='g', alpha=0.5)
plt.plot(df['MA20'], label = 'MA20', c='b', alpha = 0.9)
plt.plot(df['MA50'], label = 'MA50', c='r', alpha = 0.9)
#                  X                      Y
plt.scatter(df.iloc[Buy].index,df.iloc[Buy]['Adj Close'], marker = '^',color = 'g', s = 100)
plt.scatter(df.iloc[Sell].index,df.iloc[Sell]['Adj Close'], marker = 'v',color = 'r', s = 100)
plt.legend(loc='upper left', title='Values', fontsize='large', frameon=True, fancybox=True, shadow=True)
plt.show()
